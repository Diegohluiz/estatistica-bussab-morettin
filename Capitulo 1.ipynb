# %%
import pandas as pd

# %%
df = pd.read_csv("tabelas/tabela_2_1.csv")
df
# Out:
#      N Estado Civil   Grau de Instrução  N de Filhos Salario (x Sal Min)  \
# 0    1     solteiro  ensino fundamental          NaN                4,00
# 1    2       casado  ensino fundamental          1.0                4,56
# 2    3       casado  ensino fundamental          2.0                5,25
# 3    4     solteiro        ensino médio          NaN                5,73
# 4    5     solteiro  ensino fundamental          NaN                6,26
# 5    6       casado  ensino fundamental          0.0                6,66
# 6    7     solteiro  ensino fundamental          NaN                6,86
# 7    8     solteiro  ensino fundamental          NaN                7,39
# 8    9       casado        ensino médio          1.0                7,59
# 9   10     solteiro        ensino médio          NaN                7,44
# 10  11       casado        ensino médio          2.0                8,12
# 11  12     solteiro  ensino fundamental          NaN                8,46
# ...

# %%
df = pd.read_csv("dados/CD-CO2.csv")
df
# Out:
#               País Emissão        País.1 Emissão.1           País.2 Emissão.2
# 0      Afeganistão    0,02       Equador      0,54      Quirguistão      0,33
# 1          Albânia    0,15         Egito      0,40       Madagascar      0,02
# 2          Algéria    0,89   El Salvador      0,25           Malaui      0,02
# 3           Angola    0,12       Estônia      3,02          Malásia      1,44
# 4        Argentina    1,02       Etiópia      0,06             Mali      0,01
# 5          Armênia    0,27         Gabão      0,90       Mauritânia      0,37
# 6        Austrália    4,43        Gâmbia      0,05         Mauricio      0,36
# 7          Áustria    2,01       Geórgia      0,39           México      1,07
# 8       Azerbaijão    1,54      Alemanha      2,79         Moldávia      0,67
# 9          Camboja    0,01          Gana      0,06         Mongólia      0,94
# 10        Camarões    0,09        Grécia      1,99         Marrocos      0,30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    120 non-null    object
#  1   CO      120 non-null    object
#  2   O3      120 non-null    object
#  3   temp    120 non-null    object
#  4   umid    120 non-null    object
# dtypes: object(5)
# memory usage: 4.8+ KB
